# %% [markdown]
# **Loading data**

# %%
import pandas as pd

# %%
url_train = r"D:\My Work\For Jobs\My projects\Who wins the Big Game\Dataset\train.csv"
url_test = r"D:\My Work\For Jobs\My projects\Who wins the Big Game\Dataset\test.csv"

# %%
df_train = pd.read_csv(url_train)
df_test = pd.read_csv(url_test)

# %%
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks              Team_Value  \
# 0                                     2  Less_Than_Four_Billion
# ...

# %%
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks              Team_Value  \
# 0                                     2      Above_Four_Billion
# 1                                     3  Less_Than_Four_Billion
# 2                                     1  Less_Than_Four_Billion
# 3                                     3  Less_Than_Four_Billion
# ...

# %%
df_train.dtypes
# Out:
# Won_Championship                      int64
# Previous_SB_Wins                      int64
# Number_Of_Wins_This_Season            int64
# Number_Of_First_Round_Draft_Picks     int64
# Team_Value                           object
# Playing_Style                        object
# Average_Player_Age                    int64
# Number_Of_Injured_Players            object
# Coach_Experience_Level               object
# ID                                    int64
# dtype: object

# %%
df_test.dtypes
# Out:
# Previous_SB_Wins                      int64
# Number_Of_Wins_This_Season            int64
# Number_Of_First_Round_Draft_Picks     int64
# Team_Value                           object
# Playing_Style                        object
# Average_Player_Age                    int64
# Number_Of_Injured_Players            object
# Coach_Experience_Level               object
# ID                                    int64
# dtype: object

# %% [markdown]
# **Data Wrangling**

# %%
df_train.isnull().sum()
# Out:
# Won_Championship                     0
# Previous_SB_Wins                     0
# Number_Of_Wins_This_Season           0
# Number_Of_First_Round_Draft_Picks    0
# Team_Value                           0
# Playing_Style                        0
# Average_Player_Age                   0
# Number_Of_Injured_Players            0
# Coach_Experience_Level               0
# ID                                   0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Previous_SB_Wins                     0
# Number_Of_Wins_This_Season           0
# Number_Of_First_Round_Draft_Picks    0
# Team_Value                           0
# Playing_Style                        0
# Average_Player_Age                   0
# Number_Of_Injured_Players            0
# Coach_Experience_Level               0
# ID                                   0
# dtype: int64

# %%
team_values_train = pd.get_dummies(df_train['Team_Value'])
team_values_train.columns = ['Team_Value_Above_Four_Billion','Team_Value_Less_Than_Four_Billion','Team_Value_Less_Than_Three_Billion']
team_values_train = team_values_train.drop(['Team_Value_Less_Than_Three_Billion'],axis=1)
team_values_train
# Out:
#       Team_Value_Above_Four_Billion  Team_Value_Less_Than_Four_Billion
# 0                                 0                                  1
# 1                                 0                                  1
# 2                                 0                                  1
# 3                                 1                                  0
# 4                                 0                                  1
# ...                             ...                                ...
# 6495                              0                                  1
# 6496                              0                                  1
# 6497                              0                                  1
# 6498                              1                                  0
# 6499                              0                                  1
#
# [6500 rows x 2 columns]

# %%
team_values_test = pd.get_dummies(df_test['Team_Value'])
team_values_test.columns = ['Team_Value_Above_Four_Billion','Team_Value_Less_Than_Four_Billion','Team_Value_Less_Than_Three_Billion']
team_values_test = team_values_test.drop(['Team_Value_Less_Than_Three_Billion'],axis=1)
team_values_test
# Out:
#       Team_Value_Above_Four_Billion  Team_Value_Less_Than_Four_Billion
# 0                                 1                                  0
# 1                                 0                                  1
# 2                                 0                                  1
# 3                                 0                                  1
# 4                                 0                                  1
# ...                             ...                                ...
# 3495                              0                                  1
# 3496                              0                                  1
# 3497                              0                                  1
# 3498                              0                                  1
# 3499                              0                                  1
#
# [3500 rows x 2 columns]

# %% [markdown]
# If both Team_Value_Above_Four_Billion and Team_Value_Less_Than_Four_Billion are 0 then it's Team_Value_Less_Than_Three_Billion

# %%
df_train = pd.concat([df_train,team_values_train],axis=1)
df_train = df_train.drop(['Team_Value'],axis=1)
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks       Playing_Style  \
# 0                                     2            Balanced
# ...

# %%
df_test = pd.concat([df_test,team_values_test],axis=1)
df_test = df_test.drop(['Team_Value'],axis=1)
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks       Playing_Style  \
# 0                                     2             Relaxed
# 1                                     3            Balanced
# 2                                     1            Balanced
# 3                                     3            Balanced
# ...

# %%
playing_style_train = pd.get_dummies(df_train['Playing_Style'])
playing_style_train.columns = ['Playing_Style_Aggressive_Defense','Playing_Style_Aggressive_Offense','Playing_Style_Balanced','Playing_Style_Relaxed']
playing_style_train = playing_style_train.drop(['Playing_Style_Aggressive_Defense'],axis=1)
playing_style_train
# Out:
#       Playing_Style_Aggressive_Offense  Playing_Style_Balanced  \
# 0                                    0                       1
# 1                                    1                       0
# 2                                    0                       0
# 3                                    0                       1
# 4                                    0                       1
# ...                                ...                     ...
# 6495                                 0                       0
# 6496                                 0                       0
# 6497                                 0                       0
# 6498                                 0                       0
# 6499                                 0                       1
#
#       Playing_Style_Relaxed
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# ...

# %%
playing_style_test = pd.get_dummies(df_test['Playing_Style'])
playing_style_test.columns = ['Playing_Style_Aggressive_Defense','Playing_Style_Aggressive_Offense','Playing_Style_Balanced','Playing_Style_Relaxed']
playing_style_test = playing_style_test.drop(['Playing_Style_Aggressive_Defense'],axis=1)
playing_style_test
# Out:
#       Playing_Style_Aggressive_Offense  Playing_Style_Balanced  \
# 0                                    0                       0
# 1                                    0                       1
# 2                                    0                       1
# 3                                    0                       1
# 4                                    0                       1
# ...                                ...                     ...
# 3495                                 0                       0
# 3496                                 0                       1
# 3497                                 0                       1
# 3498                                 0                       0
# 3499                                 0                       1
#
#       Playing_Style_Relaxed
# 0                         1
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# ...

# %% [markdown]
# If all Playing_Style_Aggressive_Offense, Playing_Style_Balanced and Playing_Style_Relaxed are 0 then it's Playing_Style_Aggressive_Defense

# %%
df_train = pd.concat([df_train,playing_style_train],axis=1)
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks       Playing_Style  \
# 0                                     2            Balanced
# ...

# %%
df_test = pd.concat([df_test,playing_style_test],axis=1)
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks       Playing_Style  \
# 0                                     2             Relaxed
# 1                                     3            Balanced
# 2                                     1            Balanced
# 3                                     3            Balanced
# ...

# %%
df_train = df_train.drop(['Playing_Style'],axis=1)
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age  \
# 0                                     2                  27
# ...

# %%
df_test = df_test.drop(['Playing_Style'],axis=1)
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age  \
# 0                                     2                  26
# 1                                     3                  26
# 2                                     1                  27
# 3                                     3                  26
# ...

# %%
coach_experience_level_train = pd.get_dummies(df_train['Coach_Experience_Level'])
coach_experience_level_train.columns = ['Coach_Experience_Level_Advanced', 'Coach_Experience_Level_Beginner','Coach_Experience_Level_Intermediate']
coach_experience_level_train = coach_experience_level_train.drop(['Coach_Experience_Level_Beginner'],axis=1)
coach_experience_level_train
# Out:
#       Coach_Experience_Level_Advanced  Coach_Experience_Level_Intermediate
# 0                                   0                                    1
# 1                                   0                                    1
# 2                                   0                                    1
# 3                                   0                                    1
# 4                                   0                                    1
# ...                               ...                                  ...
# 6495                                0                                    1
# 6496                                0                                    1
# 6497                                0                                    1
# 6498                                0                                    1
# 6499                                0                                    1
#
# [6500 rows x 2 columns]

# %%
coach_experience_level_test = pd.get_dummies(df_test['Coach_Experience_Level'])
coach_experience_level_test.columns = ['Coach_Experience_Level_Advanced', 'Coach_Experience_Level_Beginner','Coach_Experience_Level_Intermediate']
coach_experience_level_test = coach_experience_level_test.drop(['Coach_Experience_Level_Beginner'],axis=1)
coach_experience_level_test
# Out:
#       Coach_Experience_Level_Advanced  Coach_Experience_Level_Intermediate
# 0                                   0                                    1
# 1                                   1                                    0
# 2                                   0                                    0
# 3                                   0                                    1
# 4                                   0                                    1
# ...                               ...                                  ...
# 3495                                0                                    0
# 3496                                0                                    1
# 3497                                0                                    1
# 3498                                0                                    1
# 3499                                0                                    1
#
# [3500 rows x 2 columns]

# %% [markdown]
# If both Coach_Experience_Level_Advanced and Coach_Experience_Level_Intermediate are 0 then it's Coach_Experience_Level_Beginner

# %%
df_train = pd.concat([df_train,coach_experience_level_train],axis=1)
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age  \
# 0                                     2                  27
# ...

# %%
df_test = pd.concat([df_test,coach_experience_level_test],axis=1)
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age  \
# 0                                     2                  26
# 1                                     3                  26
# 2                                     1                  27
# 3                                     3                  26
# ...

# %%
df_train = df_train.drop(['Coach_Experience_Level'],axis=1)
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age  \
# 0                                     2                  27
# ...

# %%
df_test = df_test.drop(['Coach_Experience_Level'],axis=1)
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age  \
# 0                                     2                  26
# 1                                     3                  26
# 2                                     1                  27
# 3                                     3                  26
# ...

# %%
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age  \
# 0                                     2                  27
# ...

# %%
df_train.dtypes
# Out:
# Won_Championship                        int64
# Previous_SB_Wins                        int64
# Number_Of_Wins_This_Season              int64
# Number_Of_First_Round_Draft_Picks       int64
# Average_Player_Age                      int64
# Number_Of_Injured_Players              object
# ID                                      int64
# Team_Value_Above_Four_Billion           uint8
# Team_Value_Less_Than_Four_Billion       uint8
# Playing_Style_Aggressive_Offense        uint8
# Playing_Style_Balanced                  uint8
# Playing_Style_Relaxed                   uint8
# Coach_Experience_Level_Advanced         uint8
# Coach_Experience_Level_Intermediate     uint8
# dtype: object

# %%
df_train['Number_Of_Injured_Players'].value_counts()
# Out:
# five     1894
# six      1799
# four     1069
# seven     972
# three     343
# eight     289
# two        78
# nine       44
# one        10
# ten         2
# Name: Number_Of_Injured_Players, dtype: int64

# %%
new_injured_players_train = []
injured_players_train = df_train['Number_Of_Injured_Players'].to_numpy()
for i in range(len(injured_players_train)):
    if(injured_players_train[i]=="five"):
        new_injured_players_train.append(5)
    elif(injured_players_train[i]=="six"):
        new_injured_players_train.append(6)
    elif(injured_players_train[i]=="four"):
        new_injured_players_train.append(4)
    elif(injured_players_train[i]=="seven"):
        new_injured_players_train.append(7)
    elif(injured_players_train[i]=="three"):
        new_injured_players_train.append(3)
    elif(injured_players_train[i]=="eight"):
        new_injured_players_train.append(8)
    elif(injured_players_train[i]=="two"):
        new_injured_players_train.append(2)
    elif(injured_players_train[i]=="nine"):
        new_injured_players_train.append(9)
    elif(injured_players_train[i]=="one"):
        new_injured_players_train.append(1)
    elif(injured_players_train[i]=="ten"):
        new_injured_players_train.append(10)

# %%
print(new_injured_players_train)
# Out:
# [5, 5, 4, 6, 5, 5, 5, 5, 4, 5, 5, 5, 4, 3, 4, 7, 4, 5, 6, 5, 4, 4, 5, 6, 6, 4, 5, 3, 5, 6, 4, 3, 8, 6, 5, 5, 5, 6, 5, 6, 5, 6, 6, 7, 6, 6, 7, 5, 5, 5, 6, 4, 5, 6, 7, 5, 6, 7, 6, 4, 6, 3, 3, 5, 6, 8, 5, 5, 7, 4, 3, 5, 6, 6, 5, 7, 6, 4, 7, 6, 3, 6, 3, 5, 4, 4, 6, 6, 6, 8, 6, 3, 5, 7, 5, 7, 2, 6, 8, 5, 5, 4, 6, 5, 5, 6, 6, 6, 7, 6, 6, 8, 5, 4, 7, 7, 7, 8, 5, 6, 6, 5, 4, 4, 5, 6, 5, 8, 7, 5, 6, 6, 7, 6, 6, 6, 3, 5, 5, 5, 7, 8, 4, 6, 4, 4, 4, 3, 6, 6, 6, 5, 4, 6, 6, 6, 5, 3, 4, 6, 4, 6, 3, 6, 6, 4, 4, 5, 6, 5, 3, 5, 7, 6, 7, 8, 7, 5, 7, 5, 5, 6, 8, 4, 6, 4, 6, 5, 5, 3, 6, 6, 6, 3, 6, 6, 7, 4, 7, 7, 6, 5, 6, 4, 4, 7, 6, 5, 3, 6, 5, 5, 5, 6, 5, 6, 5, 5, 5, 6, 3, 6, 4, 6, 6, 6, 6, 7, 6, 5, 6, 5, 5, 7, 6, 7, 5, 8, 7, 6, 6, 7, 4, 6, 6, 5, 6, 5, 5, 7, 6, 6, 4, 5, 6, 6, 3, 5, 5, 7, 4, 7, 4, 5, 4, 5, 6, 2, 5, 4, 7, 7, 6, 7, 5, 8, 5, 6, 4, 6, 7, 7, 3, 5, 6, 7, 6, 5, 8, 7, 5, 6, 6, 6, 6, 7, 6, 5, 5, 6, 7, 5, 4, 4, 4, 5, 5, 5, 4, 7, 6, 5, 6, 4, 5, 4, 5, 7, 6, 7, 7, 7, 5, 7, 5, 6, 4, 4, 7, 7, 6, 5, 7
# ...

# %%
df_injured_players_train = pd.DataFrame(new_injured_players_train)
df_injured_players_train.columns = ['Number_Of_Injured_Players']
df_injured_players_train
# Out:
#       Number_Of_Injured_Players
# 0                             5
# 1                             5
# 2                             4
# 3                             6
# 4                             5
# ...                         ...
# 6495                          3
# 6496                          7
# 6497                          5
# 6498                          6
# 6499                          8
#
# [6500 rows x 1 columns]

# %%
df_test['Number_Of_Injured_Players'].value_counts()
# Out:
# five     1008
# six       930
# four      608
# seven     570
# three     185
# eight     131
# two        33
# nine       28
# ten         5
# one         2
# Name: Number_Of_Injured_Players, dtype: int64

# %%
new_injured_players_test = []
injured_players_test = df_test['Number_Of_Injured_Players'].to_numpy()
for i in range(len(injured_players_test)):
    if(injured_players_test[i]=="five"):
        new_injured_players_test.append(5)
    elif(injured_players_test[i]=="six"):
        new_injured_players_test.append(6)
    elif(injured_players_test[i]=="four"):
        new_injured_players_test.append(4)
    elif(injured_players_test[i]=="seven"):
        new_injured_players_test.append(7)
    elif(injured_players_test[i]=="three"):
        new_injured_players_test.append(3)
    elif(injured_players_test[i]=="eight"):
        new_injured_players_test.append(8)
    elif(injured_players_test[i]=="two"):
        new_injured_players_test.append(2)
    elif(injured_players_test[i]=="nine"):
        new_injured_players_test.append(9)
    elif(injured_players_test[i]=="one"):
        new_injured_players_test.append(1)
    elif(injured_players_test[i]=="ten"):
        new_injured_players_test.append(10)

# %%
df_injured_players_test = pd.DataFrame(new_injured_players_test)
df_injured_players_test.columns = ['Number_Of_Injured_Players']
df_injured_players_test
# Out:
#       Number_Of_Injured_Players
# 0                             2
# 1                             6
# 2                             9
# 3                             7
# 4                             3
# ...                         ...
# 3495                          8
# 3496                          7
# 3497                          7
# 3498                          4
# 3499                          3
#
# [3500 rows x 1 columns]

# %%
df_train = pd.concat([df_train,df_injured_players_train],axis=1)
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age  \
# 0                                     2                  27
# ...

# %%
df_test = pd.concat([df_test,df_injured_players_test],axis=1)
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age  \
# 0                                     2                  26
# 1                                     3                  26
# 2                                     1                  27
# 3                                     3                  26
# ...

# %%
df_train = df_train.drop(['Number_Of_Injured_Players'],axis=1)
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age    ID  \
# 0                                     2                  27  6056
# ...

# %%
df_test = df_test.drop(['Number_Of_Injured_Players'],axis=1)
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age     ID  \
# 0                                     2                  26      1
# 1                                     3                  26      5
# 2                                     1                  27      6
# 3                                     3                  26      7
# ...

# %%
df_train = pd.concat([df_train,df_injured_players_train],axis=1)
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age    ID  \
# 0                                     2                  27  6056
# ...

# %%
df_test = pd.concat([df_test,df_injured_players_test],axis=1)
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age     ID  \
# 0                                     2                  26      1
# 1                                     3                  26      5
# 2                                     1                  27      6
# 3                                     3                  26      7
# ...

# %%
df_train
# Out:
#       Won_Championship  Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    0                 3                          13
# 1                    0                 2                          14
# 2                    1                 2                          13
# 3                    0                 2                          12
# 4                    0                 1                          15
# ...                ...               ...                         ...
# 6495                 0                 1                          14
# 6496                 1                 2                          14
# 6497                 1                 1                          14
# 6498                 0                 1                          14
# 6499                 0                 1                          12
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age    ID  \
# 0                                     2                  27  6056
# ...

# %%
df_test
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          16
# 1                    2                          15
# 2                    2                          10
# 3                    3                          14
# 4                    3                          13
# ...                ...                         ...
# 3495                 2                          13
# 3496                 1                          16
# 3497                 2                          13
# 3498                 1                          15
# 3499                 2                          15
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age     ID  \
# 0                                     2                  26      1
# 1                                     3                  26      5
# 2                                     1                  27      6
# 3                                     3                  26      7
# ...

# %%
y_train = df_train['Won_Championship']
x_train = df_train.drop(['Won_Championship'],axis=1)

# %%
y_train
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 6495    0
# 6496    1
# 6497    1
# 6498    0
# 6499    0
# Name: Won_Championship, Length: 6500, dtype: int64

# %%
x_train
# Out:
#       Previous_SB_Wins  Number_Of_Wins_This_Season  \
# 0                    3                          13
# 1                    2                          14
# 2                    2                          13
# 3                    2                          12
# 4                    1                          15
# ...                ...                         ...
# 6495                 1                          14
# 6496                 2                          14
# 6497                 1                          14
# 6498                 1                          14
# 6499                 1                          12
#
#       Number_Of_First_Round_Draft_Picks  Average_Player_Age    ID  \
# 0                                     2                  27  6056
# 1                                     2                  26  9702
# 2                                     1                  27  1745
# 3                                     2                  27  4757
# ...

# %%
from sklearn import neighbors

# %%
model = neighbors.KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
prediction = model.predict(df_test)

# %%
print(prediction)
# Out:
# [0 0 1 ... 0 0 0]

# %%
accuracy = model.score(df_test,prediction)
print("Accuracy is: ",accuracy)
# Out:
# Accuracy is:  1.0

# %%
df_predicted = pd.DataFrame(prediction)

# %%
df_predicted
# Out:
#       0
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# ...  ..
# 3495  1
# 3496  1
# 3497  0
# 3498  0
# 3499  0
#
# [3500 rows x 1 columns]

# %%
df = pd.concat([df_predicted,df_test['ID']],axis=1)

# %%
df
# Out:
#       0     ID
# 0     0      1
# 1     0      5
# 2     1      6
# 3     1      7
# 4     1      9
# ...  ..    ...
# 3495  1   9988
# 3496  1   9989
# 3497  0   9996
# 3498  0   9997
# 3499  0  10000
#
# [3500 rows x 2 columns]

# %%
df.columns = ['Won_Championship_Prediction', 'ID']
df
# Out:
#       Won_Championship_Prediction     ID
# 0                               0      1
# 1                               0      5
# 2                               1      6
# 3                               1      7
# 4                               1      9
# ...                           ...    ...
# 3495                            1   9988
# 3496                            1   9989
# 3497                            0   9996
# 3498                            0   9997
# 3499                            0  10000
#
# [3500 rows x 2 columns]

# %%
url_csv = "D:\My Work\For Jobs\My projects\Who wins the Big Game\Predictions.csv"

# %%
df.to_csv(url_csv)
